# %%
years_of_exp = int(input("How many years of Experience Do you have?"))
staff_age = int(input("Age: "))

if years_of_exp > 25 and staff_age >= 55:
    print("Annual Tax revenue is $5,600,000")
elif years_of_exp > 20 and staff_age >= 45:
    print("Annual Tax revenue is $4,480,000")
    
                
elif years_of_exp > 10 and age >= 35:
    print("Annual Tax revenue is $1,500,000")

else:
    print("Annual Tax revenue is 550,000")
# Out:
# How many years of Experience Do you have? 45
# Age:  55
# Annual Tax revenue is $5,600,000
